# %%
# %pip install keras-tuner
# Out:
# Collecting keras-tuner
#   Downloading keras_tuner-1.4.7-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: keras in /usr/local/lib/python3.11/dist-packages (from keras-tuner) (3.8.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from keras-tuner) (24.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from keras-tuner) (2.32.3)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl.metadata (221 bytes)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (2.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (3.13.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (0.15.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->keras-tuner) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->keras-tuner) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->keras-tuner) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->keras-tuner) (2025.1.31)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from optree->keras->keras-tuner) (4.13.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras->keras-tuner) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras->keras-tuner) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras->keras-tuner) (0.1.2)
# Downloading keras_tuner-1.4.7-py3-none-any.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 4.0 MB/s eta 0:00:00
# Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.4.7 kt-legacy-1.0.5

# %%
import pandas as pd
import numpy as np

# === Train set ===
df_LTrain_x = pd.read_csv('arkomadataset/LeftArmDataset/LTrain_x.csv')
df_LTrain_y = pd.read_csv('arkomadataset/LeftArmDataset/LTrain_y.csv')

# === Validation set ===
df_LVal_x = pd.read_csv('arkomadataset/LeftArmDataset/LVal_x.csv')
df_LVal_y = pd.read_csv('arkomadataset/LeftArmDataset/LVal_y.csv')

# === Test set ===
df_LTest_x = pd.read_csv('arkomadataset/LeftArmDataset/LTest_x.csv')
df_LTest_y = pd.read_csv('arkomadataset/LeftArmDataset/LTest_y.csv')

# Just to see how many rows/columns you have
print("Train X shape:", df_LTrain_x.shape)
print("Train Y shape:", df_LTrain_y.shape)
print("Validation X shape:", df_LVal_x.shape)
print("Validation Y shape:", df_LVal_y.shape)
print("Test X shape:", df_LTest_x.shape)
print("Test Y shape:", df_LTest_y.shape)
# Out:
# Train X shape: (6000, 6)
# Train Y shape: (6000, 5)
# Validation X shape: (2000, 6)
# Validation Y shape: (2000, 5)
# Test X shape: (2000, 6)
# Test Y shape: (2000, 5)

# %%
X_train = df_LTrain_x.values
y_train = df_LTrain_y.values

X_val = df_LVal_x.values
y_val = df_LVal_y.values

X_test = df_LTest_x.values
y_test = df_LTest_y.values

# %%
from sklearn.preprocessing import StandardScaler

# Create scalers for inputs and outputs
scaler_X = StandardScaler()
scaler_y = StandardScaler()
print(scaler_y)
# Fit scalers only on the training data and transform training, validation, and test sets:
X_train_scaled = scaler_X.fit_transform(X_train)
X_val_scaled = scaler_X.transform(X_val)
X_test_scaled = scaler_X.transform(X_test)


y_train_scaled = scaler_y.fit_transform(y_train)
y_val_scaled = scaler_y.transform(y_val)
y_test_scaled = scaler_y.transform(y_test)

print("Sample normalized input:", X_train_scaled[0])
print("Sample normalized output:", y_train_scaled[0])
# Out:
# StandardScaler()
# Sample normalized input: [-1.66424774  0.04971416 -1.27395635 -0.0678829   1.86054145  0.13048967]
# Sample normalized output: [ 1.23094922  0.60199925  0.84784477 -0.60489306 -0.75798009]

# %%
import tensorflow as tf

# New differentiable forward kinematics for a 5-DOF arm:
def forward_kinematics_tf_5(joint_angles, link_lengths):
    """
    Computes the end-effector position for a 5-DOF robotic arm.

    Parameters:
      joint_angles: Tensor of shape [batch, 5]
      link_lengths: list or array of 5 link lengths, e.g., [l1, l2, l3, l4, l5]

    Returns:
      A tensor of shape [batch, 3] representing the (x, y, z) end-effector position.
    """
    # Unpack joint angles for clarity
    theta1 = joint_angles[:, 0]  # rotation in XY plane
    theta2 = joint_angles[:, 1]  # vertical motion
    theta3 = joint_angles[:, 2]  # further extension
    theta4 = joint_angles[:, 3]
    theta5 = joint_angles[:, 4]

    # For simplicity, assume:
    # - First link rotates in XY.
    # - Each subsequent link extends the arm, adding cumulative rotations.
    # Base position:
    x0 = tf.zeros_like(theta1)
    y0 = tf.zeros_like(theta1)
    z0 = tf.zeros_like(theta1)

    # First link:
    x1 = x0 + link_lengths[0] * tf.cos(theta1)
    y1 = y0 + link_lengths[0] * tf.sin(theta1)
    z1 = z0  # no vertical movement yet

    # Second link:
    x2 = x1 + link_lengths[1] * tf.cos(theta1) * tf.cos(theta2)
    y2 = y1 + link_lengths[1] * tf.sin(theta1) * tf.cos(theta2)
    z2 = z1 + link_lengths[1] * tf.sin(theta2)

    # Third link:
    x3 = x2 + link_lengths[2] * tf.cos(theta1) * tf.cos(theta2 + theta3)
    y3 = y2 + link_lengths[2] * tf.sin(theta1) * tf.cos(theta2 + theta3)
    z3 = z2 + link_lengths[2] * tf.sin(theta2 + theta3)

    # Fourth link:
    x4 = x3 + link_lengths[3] * tf.cos(theta1) * tf.cos(theta2 + theta3 + theta4)
    y4 = y3 + link_lengths[3] * tf.sin(theta1) * tf.cos(theta2 + theta3 + theta4)
    z4 = z3 + link_lengths[3] * tf.sin(theta2 + theta3 + theta4)

    # Fifth link:
    x5 = x4 + link_lengths[4] * tf.cos(theta1) * tf.cos(theta2 + theta3 + theta4 + theta5)
    y5 = y4 + link_lengths[4] * tf.sin(theta1) * tf.cos(theta2 + theta3 + theta4 + theta5)
    z5 = z4 + link_lengths[4] * tf.sin(theta2 + theta3 + theta4 + theta5)

    return tf.stack([x5, y5, z5], axis=1)  # shape: [batch, 3]

# %%
# Custom PINN model for 5-DOF outputs:
class PINNModel(tf.keras.Model):
    def __init__(self, link_lengths, lambda_phys=0.1, **kwargs):
        super(PINNModel, self).__init__(**kwargs)
        self.link_lengths = link_lengths  # Expecting a list of 5 link lengths
        self.lambda_phys = lambda_phys    # Weight for physics loss
        # Define network layers
        self.d1 = tf.keras.layers.Dense(64, activation='relu')
        self.d2 = tf.keras.layers.Dense(64, activation='relu')
        self.dropout = tf.keras.layers.Dropout(0.2)
        self.d3 = tf.keras.layers.Dense(32, activation='relu')
        # Updated: output 5 values (instead of 3)
        self.out_layer = tf.keras.layers.Dense(5, activation='linear')

    def call(self, inputs, training=False):
        x = self.d1(inputs)
        x = self.d2(x)
        if training:
            x = self.dropout(x, training=training)
        x = self.d3(x)
        return self.out_layer(x)

    def train_step(self, data):
        # Unpack data: x = input features, y = ground truth joint angles (shape [batch, 5])
        x, y = data
        with tf.GradientTape() as tape:
            y_pred = self(x, training=True)  # predicted joint angles, shape [batch, 5]

            # Standard data loss (MSE) between predictions and true joint angles
            loss_data = tf.reduce_mean(tf.square(y - y_pred))

            # Physics loss:
            # - Compute predicted end-effector position using our differentiable forward kinematics.
            # - Assume x[:, :3] contains the target [x,y,z] of the end-effector.
            pred_positions = forward_kinematics_tf_5(y_pred, self.link_lengths)
            target_positions = x[:, :3]
            loss_phys = tf.reduce_mean(tf.square(target_positions - pred_positions))

            # Total loss: data loss plus weighted physics loss
            loss = loss_data + self.lambda_phys * loss_phys

        gradients = tape.gradient(loss, self.trainable_variables)
        self.optimizer.apply_gradients(zip(gradients, self.trainable_variables))
        return {"loss": loss, "data_loss": loss_data, "phys_loss": loss_phys}

# %%
# Example usage in Google Colab:

# Define link lengths for a 5-DOF arm (you may adjust these values)
link_lengths = [1.0, 1.0, 0.8, 0.5, 0.3]
pinn_model = PINNModel(link_lengths=link_lengths, lambda_phys=0.1)

# Compile the model
pinn_model.compile(optimizer='adam', loss=lambda y_true, y_pred: tf.constant(0.0))


# Now train the model using your prepared data.
# Make sure X_train_scaled has target positions in its first 3 columns.
# Also ensure that y_train_scaled has 5 columns (the first 5 columns of your original y targets).
history_pinn = pinn_model.fit(X_train_scaled, y_train_scaled,
                              epochs=200, batch_size=64,
                              validation_data=(X_val_scaled, y_val_scaled))

# # Save the model to download
# pinn_model.save("pinn_model.h5")
# Out:
# Epoch 1/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - data_loss: 0.6902 - loss: 0.9856 - phys_loss: 2.9542 - val_loss: 0.0000e+00
# Epoch 2/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.5085 - loss: 0.7337 - phys_loss: 2.2515 - val_loss: 0.0000e+00
# Epoch 3/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.4109 - loss: 0.6257 - phys_loss: 2.1478 - val_loss: 0.0000e+00
# Epoch 4/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.3326 - loss: 0.5435 - phys_loss: 2.1095 - val_loss: 0.0000e+00
# Epoch 5/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - data_loss: 0.2865 - loss: 0.4923 - phys_loss: 2.0579 - val_loss: 0.0000e+00
# Epoch 6/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - data_loss: 0.2586 - loss: 0.4632 - phys_loss: 2.0457 - val_loss: 0.0000e+00
# Epoch 7/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.2456 - loss: 0.4486 - phys_loss: 2.0299 - val_loss: 0.0000e+00
# Epoch 8/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.2330 - loss: 0.4346 - phys_loss: 2.0159 - val_loss: 0.0000e+00
# Epoch 9/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.2248 - loss: 0.4261 - phys_loss: 2.0128 - val_loss: 0.0000e+00
# Epoch 10/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.2126 - loss: 0.4139 - phys_loss: 2.0126 - val_loss: 0.0000e+00
# Epoch 11/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.2041 - loss: 0.4031 - phys_loss: 1.9901 - val_loss: 0.0000e+00
# Epoch 12/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.2010 - loss: 0.4017 - phys_loss: 2.0069 - val_loss: 0.0000e+00
# Epoch 13/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.1924 - loss: 0.3918 - phys_loss: 1.9945 - val_loss: 0.0000e+00
# Epoch 14/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - data_loss: 0.1895 - loss: 0.3875 - phys_loss: 1.9804 - val_loss: 0.0000e+00
# Epoch 15/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - data_loss: 0.1842 - loss: 0.3824 - phys_loss: 1.9825 - val_loss: 0.0000e+00
# Epoch 16/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - data_loss: 0.1776 - loss: 0.3764 - phys_loss: 1.9877 - val_loss: 0.0000e+00
# Epoch 17/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.1759 - loss: 0.3756 - phys_loss: 1.9968 - val_loss: 0.0000e+00
# Epoch 18/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.1719 - loss: 0.3691 - phys_loss: 1.9718 - val_loss: 0.0000e+00
# Epoch 19/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.1698 - loss: 0.3669 - phys_loss: 1.9712 - val_loss: 0.0000e+00
# Epoch 20/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - data_loss: 0.1634 - loss: 0.3610 - phys_loss: 1.9759 - val_loss: 0.0000e+00
# Epoch 21/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.1648 - loss: 0.3612 - phys_loss: 1.9636 - val_loss: 0.0000e+00
# Epoch 22/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.1587 - loss: 0.3542 - phys_loss: 1.9555 - val_loss: 0.0000e+00
# Epoch 23/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.1558 - loss: 0.3519 - phys_loss: 1.9611 - val_loss: 0.0000e+00
# Epoch 24/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.1565 - loss: 0.3517 - phys_loss: 1.9527 - val_loss: 0.0000e+00
# Epoch 25/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - data_loss: 0.1528 - loss: 0.3474 - phys_loss: 1.9461 - val_loss: 0.0000e+00
# Epoch 26/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - data_loss: 0.1504 - loss: 0.3451 - phys_loss: 1.9468 - val_loss: 0.0000e+00
# Epoch 27/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.1519 - loss: 0.3466 - phys_loss: 1.9462 - val_loss: 0.0000e+00
# Epoch 28/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.1472 - loss: 0.3404 - phys_loss: 1.9324 - val_loss: 0.0000e+00
# Epoch 29/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.1448 - loss: 0.3389 - phys_loss: 1.9408 - val_loss: 0.0000e+00
# Epoch 30/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.1457 - loss: 0.3376 - phys_loss: 1.9183 - val_loss: 0.0000e+00
# Epoch 31/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.1432 - loss: 0.3354 - phys_loss: 1.9226 - val_loss: 0.0000e+00
# Epoch 32/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.1437 - loss: 0.3347 - phys_loss: 1.9108 - val_loss: 0.0000e+00
# Epoch 33/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - data_loss: 0.1408 - loss: 0.3320 - phys_loss: 1.9119 - val_loss: 0.0000e+00
# Epoch 34/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.1387 - loss: 0.3314 - phys_loss: 1.9268 - val_loss: 0.0000e+00
# Epoch 35/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.1364 - loss: 0.3272 - phys_loss: 1.9084 - val_loss: 0.0000e+00
# Epoch 36/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.1372 - loss: 0.3286 - phys_loss: 1.9149 - val_loss: 0.0000e+00
# Epoch 37/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - data_loss: 0.1365 - loss: 0.3269 - phys_loss: 1.9047 - val_loss: 0.0000e+00
# Epoch 38/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - data_loss: 0.1358 - loss: 0.3255 - phys_loss: 1.8979 - val_loss: 0.0000e+00
# Epoch 39/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - data_loss: 0.1335 - loss: 0.3236 - phys_loss: 1.9008 - val_loss: 0.0000e+00
# Epoch 40/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - data_loss: 0.1324 - loss: 0.3223 - phys_loss: 1.8989 - val_loss: 0.0000e+00
# Epoch 41/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.1331 - loss: 0.3226 - phys_loss: 1.8949 - val_loss: 0.0000e+00
# Epoch 42/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.1333 - loss: 0.3220 - phys_loss: 1.8864 - val_loss: 0.0000e+00
# Epoch 43/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.1329 - loss: 0.3218 - phys_loss: 1.8893 - val_loss: 0.0000e+00
# Epoch 44/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - data_loss: 0.1301 - loss: 0.3186 - phys_loss: 1.8852 - val_loss: 0.0000e+00
# Epoch 45/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - data_loss: 0.1321 - loss: 0.3205 - phys_loss: 1.8837 - val_loss: 0.0000e+00
# Epoch 46/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.1310 - loss: 0.3187 - phys_loss: 1.8776 - val_loss: 0.0000e+00
# Epoch 47/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.1282 - loss: 0.3171 - phys_loss: 1.8888 - val_loss: 0.0000e+00
# Epoch 48/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.1283 - loss: 0.3156 - phys_loss: 1.8735 - val_loss: 0.0000e+00
# Epoch 49/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.1288 - loss: 0.3161 - phys_loss: 1.8729 - val_loss: 0.0000e+00
# Epoch 50/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.1268 - loss: 0.3133 - phys_loss: 1.8649 - val_loss: 0.0000e+00
# Epoch 51/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.1272 - loss: 0.3139 - phys_loss: 1.8673 - val_loss: 0.0000e+00
# Epoch 52/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.1246 - loss: 0.3114 - phys_loss: 1.8673 - val_loss: 0.0000e+00
# Epoch 53/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.1292 - loss: 0.3150 - phys_loss: 1.8581 - val_loss: 0.0000e+00
# Epoch 54/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.1248 - loss: 0.3102 - phys_loss: 1.8544 - val_loss: 0.0000e+00
# Epoch 55/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.1232 - loss: 0.3098 - phys_loss: 1.8666 - val_loss: 0.0000e+00
# Epoch 56/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - data_loss: 0.1249 - loss: 0.3113 - phys_loss: 1.8643 - val_loss: 0.0000e+00
# Epoch 57/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.1267 - loss: 0.3120 - phys_loss: 1.8527 - val_loss: 0.0000e+00
# Epoch 58/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - data_loss: 0.1229 - loss: 0.3095 - phys_loss: 1.8658 - val_loss: 0.0000e+00
# Epoch 59/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.1227 - loss: 0.3078 - phys_loss: 1.8514 - val_loss: 0.0000e+00
# Epoch 60/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.1234 - loss: 0.3097 - phys_loss: 1.8628 - val_loss: 0.0000e+00
# Epoch 61/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - data_loss: 0.1220 - loss: 0.3070 - phys_loss: 1.8502 - val_loss: 0.0000e+00
# Epoch 62/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - data_loss: 0.1236 - loss: 0.3084 - phys_loss: 1.8488 - val_loss: 0.0000e+00
# Epoch 63/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - data_loss: 0.1238 - loss: 0.3077 - phys_loss: 1.8396 - val_loss: 0.0000e+00
# Epoch 64/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - data_loss: 0.1212 - loss: 0.3060 - phys_loss: 1.8479 - val_loss: 0.0000e+00
# Epoch 65/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.1224 - loss: 0.3061 - phys_loss: 1.8369 - val_loss: 0.0000e+00
# Epoch 66/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.1202 - loss: 0.3044 - phys_loss: 1.8414 - val_loss: 0.0000e+00
# Epoch 67/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.1187 - loss: 0.3023 - phys_loss: 1.8354 - val_loss: 0.0000e+00
# Epoch 68/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.1198 - loss: 0.3044 - phys_loss: 1.8451 - val_loss: 0.0000e+00
# Epoch 69/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.1203 - loss: 0.3043 - phys_loss: 1.8403 - val_loss: 0.0000e+00
# Epoch 70/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.1224 - loss: 0.3062 - phys_loss: 1.8379 - val_loss: 0.0000e+00
# Epoch 71/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.1194 - loss: 0.3034 - phys_loss: 1.8394 - val_loss: 0.0000e+00
# Epoch 72/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.1188 - loss: 0.3027 - phys_loss: 1.8388 - val_loss: 0.0000e+00
# Epoch 73/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - data_loss: 0.1180 - loss: 0.3027 - phys_loss: 1.8471 - val_loss: 0.0000e+00
# Epoch 74/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.1204 - loss: 0.3039 - phys_loss: 1.8357 - val_loss: 0.0000e+00
# Epoch 75/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.1180 - loss: 0.3025 - phys_loss: 1.8450 - val_loss: 0.0000e+00
# Epoch 76/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.1198 - loss: 0.3032 - phys_loss: 1.8343 - val_loss: 0.0000e+00
# Epoch 77/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.1159 - loss: 0.2996 - phys_loss: 1.8370 - val_loss: 0.0000e+00
# Epoch 78/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.1176 - loss: 0.3006 - phys_loss: 1.8300 - val_loss: 0.0000e+00
# Epoch 79/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.1194 - loss: 0.3031 - phys_loss: 1.8373 - val_loss: 0.0000e+00
# Epoch 80/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.1158 - loss: 0.2994 - phys_loss: 1.8363 - val_loss: 0.0000e+00
# Epoch 81/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - data_loss: 0.1175 - loss: 0.2996 - phys_loss: 1.8202 - val_loss: 0.0000e+00
# Epoch 82/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.1171 - loss: 0.3001 - phys_loss: 1.8300 - val_loss: 0.0000e+00
# Epoch 83/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.1168 - loss: 0.2998 - phys_loss: 1.8300 - val_loss: 0.0000e+00
# Epoch 84/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.1156 - loss: 0.2982 - phys_loss: 1.8257 - val_loss: 0.0000e+00
# Epoch 85/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.1145 - loss: 0.2968 - phys_loss: 1.8229 - val_loss: 0.0000e+00
# Epoch 86/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.1150 - loss: 0.2971 - phys_loss: 1.8208 - val_loss: 0.0000e+00
# Epoch 87/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - data_loss: 0.1140 - loss: 0.2968 - phys_loss: 1.8286 - val_loss: 0.0000e+00
# Epoch 88/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - data_loss: 0.1151 - loss: 0.2978 - phys_loss: 1.8273 - val_loss: 0.0000e+00
# Epoch 89/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - data_loss: 0.1165 - loss: 0.2989 - phys_loss: 1.8240 - val_loss: 0.0000e+00
# Epoch 90/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.1161 - loss: 0.2981 - phys_loss: 1.8199 - val_loss: 0.0000e+00
# Epoch 91/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.1126 - loss: 0.2953 - phys_loss: 1.8268 - val_loss: 0.0000e+00
# Epoch 92/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - data_loss: 0.1139 - loss: 0.2958 - phys_loss: 1.8186 - val_loss: 0.0000e+00
# Epoch 93/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.1132 - loss: 0.2955 - phys_loss: 1.8228 - val_loss: 0.0000e+00
# Epoch 94/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.1138 - loss: 0.2967 - phys_loss: 1.8288 - val_loss: 0.0000e+00
# Epoch 95/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.1130 - loss: 0.2949 - phys_loss: 1.8192 - val_loss: 0.0000e+00
# Epoch 96/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.1139 - loss: 0.2958 - phys_loss: 1.8192 - val_loss: 0.0000e+00
# Epoch 97/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.1132 - loss: 0.2947 - phys_loss: 1.8150 - val_loss: 0.0000e+00
# Epoch 98/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.1127 - loss: 0.2941 - phys_loss: 1.8142 - val_loss: 0.0000e+00
# Epoch 99/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.1130 - loss: 0.2943 - phys_loss: 1.8125 - val_loss: 0.0000e+00
# Epoch 100/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.1120 - loss: 0.2948 - phys_loss: 1.8282 - val_loss: 0.0000e+00
# Epoch 101/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.1127 - loss: 0.2950 - phys_loss: 1.8226 - val_loss: 0.0000e+00
# Epoch 102/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.1099 - loss: 0.2916 - phys_loss: 1.8170 - val_loss: 0.0000e+00
# Epoch 103/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - data_loss: 0.1117 - loss: 0.2931 - phys_loss: 1.8142 - val_loss: 0.0000e+00
# Epoch 104/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - data_loss: 0.1131 - loss: 0.2945 - phys_loss: 1.8139 - val_loss: 0.0000e+00
# Epoch 105/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.1100 - loss: 0.2914 - phys_loss: 1.8137 - val_loss: 0.0000e+00
# Epoch 106/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - data_loss: 0.1104 - loss: 0.2922 - phys_loss: 1.8183 - val_loss: 0.0000e+00
# Epoch 107/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - data_loss: 0.1089 - loss: 0.2902 - phys_loss: 1.8123 - val_loss: 0.0000e+00
# Epoch 108/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - data_loss: 0.1098 - loss: 0.2907 - phys_loss: 1.8086 - val_loss: 0.0000e+00
# Epoch 109/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - data_loss: 0.1109 - loss: 0.2929 - phys_loss: 1.8204 - val_loss: 0.0000e+00
# Epoch 110/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - data_loss: 0.1117 - loss: 0.2930 - phys_loss: 1.8132 - val_loss: 0.0000e+00
# Epoch 111/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.1117 - loss: 0.2931 - phys_loss: 1.8144 - val_loss: 0.0000e+00
# Epoch 112/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.1114 - loss: 0.2927 - phys_loss: 1.8128 - val_loss: 0.0000e+00
# Epoch 113/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.1097 - loss: 0.2904 - phys_loss: 1.8073 - val_loss: 0.0000e+00
# Epoch 114/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - data_loss: 0.1121 - loss: 0.2929 - phys_loss: 1.8078 - val_loss: 0.0000e+00
# Epoch 115/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.1114 - loss: 0.2915 - phys_loss: 1.8011 - val_loss: 0.0000e+00
# Epoch 116/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.1090 - loss: 0.2901 - phys_loss: 1.8119 - val_loss: 0.0000e+00
# Epoch 117/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.1100 - loss: 0.2899 - phys_loss: 1.7991 - val_loss: 0.0000e+00
# Epoch 118/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - data_loss: 0.1068 - loss: 0.2882 - phys_loss: 1.8144 - val_loss: 0.0000e+00
# Epoch 119/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - data_loss: 0.1078 - loss: 0.2881 - phys_loss: 1.8032 - val_loss: 0.0000e+00
# Epoch 120/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.1093 - loss: 0.2897 - phys_loss: 1.8042 - val_loss: 0.0000e+00
# Epoch 121/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.1095 - loss: 0.2904 - phys_loss: 1.8099 - val_loss: 0.0000e+00
# Epoch 122/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.1081 - loss: 0.2897 - phys_loss: 1.8160 - val_loss: 0.0000e+00
# Epoch 123/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.1088 - loss: 0.2896 - phys_loss: 1.8084 - val_loss: 0.0000e+00
# Epoch 124/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.1099 - loss: 0.2900 - phys_loss: 1.8009 - val_loss: 0.0000e+00
# Epoch 125/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.1098 - loss: 0.2908 - phys_loss: 1.8102 - val_loss: 0.0000e+00
# Epoch 126/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.1068 - loss: 0.2874 - phys_loss: 1.8062 - val_loss: 0.0000e+00
# Epoch 127/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.1091 - loss: 0.2892 - phys_loss: 1.8017 - val_loss: 0.0000e+00
# Epoch 128/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.1089 - loss: 0.2904 - phys_loss: 1.8145 - val_loss: 0.0000e+00
# Epoch 129/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.1076 - loss: 0.2883 - phys_loss: 1.8067 - val_loss: 0.0000e+00
# Epoch 130/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.1079 - loss: 0.2875 - phys_loss: 1.7961 - val_loss: 0.0000e+00
# Epoch 131/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.1047 - loss: 0.2857 - phys_loss: 1.8102 - val_loss: 0.0000e+00
# Epoch 132/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - data_loss: 0.1088 - loss: 0.2895 - phys_loss: 1.8075 - val_loss: 0.0000e+00
# Epoch 133/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - data_loss: 0.1070 - loss: 0.2875 - phys_loss: 1.8049 - val_loss: 0.0000e+00
# Epoch 134/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - data_loss: 0.1075 - loss: 0.2880 - phys_loss: 1.8048 - val_loss: 0.0000e+00
# Epoch 135/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - data_loss: 0.1063 - loss: 0.2862 - phys_loss: 1.7988 - val_loss: 0.0000e+00
# Epoch 136/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.1071 - loss: 0.2872 - phys_loss: 1.8017 - val_loss: 0.0000e+00
# Epoch 137/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - data_loss: 0.1070 - loss: 0.2871 - phys_loss: 1.8015 - val_loss: 0.0000e+00
# Epoch 138/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.1060 - loss: 0.2860 - phys_loss: 1.8000 - val_loss: 0.0000e+00
# Epoch 139/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.1047 - loss: 0.2856 - phys_loss: 1.8094 - val_loss: 0.0000e+00
# Epoch 140/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.1058 - loss: 0.2861 - phys_loss: 1.8034 - val_loss: 0.0000e+00
# Epoch 141/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.1074 - loss: 0.2876 - phys_loss: 1.8020 - val_loss: 0.0000e+00
# Epoch 142/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.1047 - loss: 0.2845 - phys_loss: 1.7981 - val_loss: 0.0000e+00
# Epoch 143/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.1048 - loss: 0.2856 - phys_loss: 1.8080 - val_loss: 0.0000e+00
# Epoch 144/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.1061 - loss: 0.2867 - phys_loss: 1.8065 - val_loss: 0.0000e+00
# Epoch 145/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - data_loss: 0.1059 - loss: 0.2864 - phys_loss: 1.8050 - val_loss: 0.0000e+00
# Epoch 146/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.1036 - loss: 0.2831 - phys_loss: 1.7950 - val_loss: 0.0000e+00
# Epoch 147/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.1078 - loss: 0.2877 - phys_loss: 1.7991 - val_loss: 0.0000e+00
# Epoch 148/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.1041 - loss: 0.2841 - phys_loss: 1.7999 - val_loss: 0.0000e+00
# Epoch 149/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.1060 - loss: 0.2864 - phys_loss: 1.8034 - val_loss: 0.0000e+00
# Epoch 150/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.1069 - loss: 0.2865 - phys_loss: 1.7954 - val_loss: 0.0000e+00
# Epoch 151/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.1065 - loss: 0.2868 - phys_loss: 1.8032 - val_loss: 0.0000e+00
# Epoch 152/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.1064 - loss: 0.2861 - phys_loss: 1.7970 - val_loss: 0.0000e+00
# Epoch 153/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.1044 - loss: 0.2830 - phys_loss: 1.7861 - val_loss: 0.0000e+00
# Epoch 154/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - data_loss: 0.1044 - loss: 0.2847 - phys_loss: 1.8026 - val_loss: 0.0000e+00
# Epoch 155/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - data_loss: 0.1057 - loss: 0.2859 - phys_loss: 1.8020 - val_loss: 0.0000e+00
# Epoch 156/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - data_loss: 0.1056 - loss: 0.2854 - phys_loss: 1.7976 - val_loss: 0.0000e+00
# Epoch 157/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - data_loss: 0.1047 - loss: 0.2849 - phys_loss: 1.8021 - val_loss: 0.0000e+00
# Epoch 158/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.1057 - loss: 0.2856 - phys_loss: 1.7996 - val_loss: 0.0000e+00
# Epoch 159/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.1047 - loss: 0.2843 - phys_loss: 1.7959 - val_loss: 0.0000e+00
# Epoch 160/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - data_loss: 0.1046 - loss: 0.2836 - phys_loss: 1.7895 - val_loss: 0.0000e+00
# Epoch 161/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - data_loss: 0.1033 - loss: 0.2819 - phys_loss: 1.7859 - val_loss: 0.0000e+00
# Epoch 162/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - data_loss: 0.1038 - loss: 0.2835 - phys_loss: 1.7970 - val_loss: 0.0000e+00
# Epoch 163/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.1050 - loss: 0.2844 - phys_loss: 1.7936 - val_loss: 0.0000e+00
# Epoch 164/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.1040 - loss: 0.2844 - phys_loss: 1.8040 - val_loss: 0.0000e+00
# Epoch 165/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.1046 - loss: 0.2837 - phys_loss: 1.7915 - val_loss: 0.0000e+00
# Epoch 166/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.1042 - loss: 0.2838 - phys_loss: 1.7958 - val_loss: 0.0000e+00
# Epoch 167/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - data_loss: 0.1044 - loss: 0.2839 - phys_loss: 1.7953 - val_loss: 0.0000e+00
# Epoch 168/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.1035 - loss: 0.2830 - phys_loss: 1.7951 - val_loss: 0.0000e+00
# Epoch 169/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - data_loss: 0.1028 - loss: 0.2826 - phys_loss: 1.7974 - val_loss: 0.0000e+00
# Epoch 170/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - data_loss: 0.1047 - loss: 0.2843 - phys_loss: 1.7964 - val_loss: 0.0000e+00
# Epoch 171/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - data_loss: 0.1019 - loss: 0.2803 - phys_loss: 1.7840 - val_loss: 0.0000e+00
# Epoch 172/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - data_loss: 0.1027 - loss: 0.2818 - phys_loss: 1.7912 - val_loss: 0.0000e+00
# Epoch 173/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.1022 - loss: 0.2812 - phys_loss: 1.7900 - val_loss: 0.0000e+00
# Epoch 174/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.1022 - loss: 0.2809 - phys_loss: 1.7872 - val_loss: 0.0000e+00
# Epoch 175/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.1036 - loss: 0.2833 - phys_loss: 1.7970 - val_loss: 0.0000e+00
# Epoch 176/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - data_loss: 0.1023 - loss: 0.2822 - phys_loss: 1.7990 - val_loss: 0.0000e+00
# Epoch 177/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - data_loss: 0.1033 - loss: 0.2827 - phys_loss: 1.7940 - val_loss: 0.0000e+00
# Epoch 178/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - data_loss: 0.1032 - loss: 0.2827 - phys_loss: 1.7955 - val_loss: 0.0000e+00
# Epoch 179/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.1029 - loss: 0.2810 - phys_loss: 1.7811 - val_loss: 0.0000e+00
# Epoch 180/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.1017 - loss: 0.2810 - phys_loss: 1.7928 - val_loss: 0.0000e+00
# Epoch 181/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - data_loss: 0.1028 - loss: 0.2815 - phys_loss: 1.7868 - val_loss: 0.0000e+00
# Epoch 182/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.1032 - loss: 0.2828 - phys_loss: 1.7953 - val_loss: 0.0000e+00
# Epoch 183/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.1018 - loss: 0.2804 - phys_loss: 1.7864 - val_loss: 0.0000e+00
# Epoch 184/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.1041 - loss: 0.2818 - phys_loss: 1.7772 - val_loss: 0.0000e+00
# Epoch 185/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.1030 - loss: 0.2823 - phys_loss: 1.7930 - val_loss: 0.0000e+00
# Epoch 186/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.1027 - loss: 0.2821 - phys_loss: 1.7943 - val_loss: 0.0000e+00
# Epoch 187/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.1025 - loss: 0.2812 - phys_loss: 1.7875 - val_loss: 0.0000e+00
# Epoch 188/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.1005 - loss: 0.2793 - phys_loss: 1.7879 - val_loss: 0.0000e+00
# Epoch 189/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - data_loss: 0.1021 - loss: 0.2805 - phys_loss: 1.7836 - val_loss: 0.0000e+00
# Epoch 190/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.1021 - loss: 0.2802 - phys_loss: 1.7815 - val_loss: 0.0000e+00
# Epoch 191/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.1034 - loss: 0.2826 - phys_loss: 1.7916 - val_loss: 0.0000e+00
# Epoch 192/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.1006 - loss: 0.2801 - phys_loss: 1.7951 - val_loss: 0.0000e+00
# Epoch 193/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.1021 - loss: 0.2803 - phys_loss: 1.7820 - val_loss: 0.0000e+00
# Epoch 194/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.1016 - loss: 0.2806 - phys_loss: 1.7896 - val_loss: 0.0000e+00
# Epoch 195/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - data_loss: 0.1020 - loss: 0.2810 - phys_loss: 1.7901 - val_loss: 0.0000e+00
# Epoch 196/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - data_loss: 0.1022 - loss: 0.2809 - phys_loss: 1.7875 - val_loss: 0.0000e+00
# Epoch 197/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.1012 - loss: 0.2798 - phys_loss: 1.7858 - val_loss: 0.0000e+00
# Epoch 198/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - data_loss: 0.1020 - loss: 0.2804 - phys_loss: 1.7837 - val_loss: 0.0000e+00
# Epoch 199/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - data_loss: 0.1020 - loss: 0.2810 - phys_loss: 1.7895 - val_loss: 0.0000e+00
# Epoch 200/200
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - data_loss: 0.1024 - loss: 0.2804 - phys_loss: 1.7808 - val_loss: 0.0000e+00

# %%
# Cell 4: import Keras Tuner & define build_pinn
import keras_tuner as kt
from tensorflow import keras

def build_pinn(hp):
    # sample hyperparameters
    units1 = hp.Int("units1", 32, 128, step=32)
    units2 = hp.Int("units2", 32, 128, step=32)
    lr     = hp.Float("lr", 1e-4, 1e-2, sampling="log")
    drop   = hp.Float("drop", 0.0, 0.5, step=0.1)
    lam    = hp.Float("lambda_phys", 0.0, 1.0, step=0.1)

    # build your PINNModel
    model = PINNModel(link_lengths, lambda_phys=lam)
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=lr),
        loss=lambda y_true, y_pred: tf.constant(0.0)
    )
    return model

# %%
# Cell 5: set up Bayesian tuner and search
tuner = kt.BayesianOptimization(
    build_pinn,
    objective=kt.Objective("loss", direction="min"),
    max_trials=20,
    num_initial_points=5,
    directory="kt_dir",
    project_name="pinn_bayes"
)

tuner.search(
    X_train_scaled, y_train_scaled,
    epochs=100,
    validation_data=(X_val_scaled, y_val_scaled),
    callbacks=[tf.keras.callbacks.EarlyStopping(patience=5)]
)
# Out:
# Trial 20 Complete [00h 00m 11s]
# loss: 0.0899258479475975
#
# Best loss So Far: 0.06188662722706795
# Total elapsed time: 00h 04m 45s

# %%
# Cell 6: retrieve best hyperparameters and rebuild
best_hp = tuner.get_best_hyperparameters(num_trials=1)[0]
best_model = build_pinn(best_hp)
best_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=best_hp.get("lr")),
    loss="mse",
    metrics=["mae"]
)

# … you can now retrain best_model or evaluate directly

# Cell 6: Retrieve and save the best model
# (place after tuner.search in your notebook)

# 1. Get the single best Keras model
# best_model = tuner.get_best_models(num_models=1)[0]

# Cell 6: Evaluate on your held-out test set
# If you trained the best model via build_pinn(best_hp), call that:
test_loss, test_mae = best_model.evaluate(X_test_scaled, y_test_scaled)

print("Test MSE:", test_loss)
print("Test MAE:", test_mae)


# 3. Save to disk in HDF5 or SavedModel format
best_model.save('pinn_model.keras')
# best_model.save("pinn_model.h5")              # HDF5 file :contentReference[oaicite:6]{index=6}
# or
# best_model.save("pinn_best_model_savedmodel",        # SavedModel directory
#                 save_format="tf")
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.3204 - mae: 0.9148
# Test MSE: 1.1641297340393066
# Test MAE: 0.8622229695320129
